# %%
word="sandip"
for i in range(len(word)-1):
 print(word[i])
# Out:
# s
# a
# n
# d
# i

# %%
word="sandip"
for i in range(len(word)-1,-1,-1):
  print(word[i])
# Out:
# p
# i
# d
# n
# a
# s

# %%
vowels="aeiou"
word="education"
count=0
for char in word:
  if char in vowels:
     count+=1
     print(f"total vowels in {word} is {count}")
# Out:
# total vowels in education is 1
# total vowels in education is 2
# total vowels in education is 3
# total vowels in education is 4
# total vowels in education is 5

# %%
string="bhavesh"
string[2:-1]
# Out:
# 'aves'
