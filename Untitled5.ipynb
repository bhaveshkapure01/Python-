# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
print(a.intersection(b))
print(a.union(b))
# Out:
# {9, 2, 3}
# {1, 2, 3, 4, 5, 7, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
print(a&b)
print(a|b)
print(a-b)
# Out:
# {9, 2, 3}
# {1, 2, 3, 4, 5, 7, 9}
# {1, 4}

# %%
dct={1:"nitin",2:"yash",3:"bhavesh",4:"shrikant",5:"abhay"}
for i,j in dct.items():
 print(i,j)
# Out:
# 1 nitin
# 2 yash
# 3 bhavesh
# 4 shrikant
# 5 abhay

# %%
dct={1:"nitin",2:"yash",3:"bhavesh",4:"shrikant",5:"abhay"}
for i,j in dct.items():
 print(f"ROLL No{i} is {j}")
# Out:
# ROLL No1 is nitin
# ROLL No2 is yash
# ROLL No3 is bhavesh
# ROLL No4 is shrikant
# ROLL No5 is abhay

# %%
dct[2]="aditya"
print(dct)
# Out:
# {1: 'nitin', 2: 'aditya', 3: 'bhavesh', 4: 'shrikant', 5: 'abhay'}

# %%
dct[6]="nitin"
print(dct)
# Out:
# {1: 'nitin', 2: 'aditya', 3: 'bhavesh', 4: 'shrikant', 5: 'abhay', 6: 'nitin'}

# %%
dct.get(2)
# Out:
# 'aditya'

# %%
dct.get(50,"not found")
# Out:
# 'not found'

# %%
sample={"days":("mom","tue","wed","thu"),
        "planets":("sun","moon","earth")}
for keys,values in sample.items():
      print(values)
# Out:
# ('mom', 'tue', 'wed', 'thu')
# ('sun', 'moon', 'earth')

# %%
n=int(input("enter a input:"))
for i in range(n,0,-1):
  for j in range(i):
    print("*",end=" ")
# Out:
# enter a input:6
# * * * * * * * * * * * * * * * * * * * * *

# %%
n=5
for i in range(n,0,-1):
  for j in range(i):
    print("*",end="")
print()
# Out:
# ***************
