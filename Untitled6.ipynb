# %%
n=int(input())
n=n*2
print(n)
# Out:
# 2
# 4

# %%
lst=[1,2,3,4,5,6,7,8,9]
to_search=int(input())
key=0
for i in range(len(lst)):
  if lst[i]==key:
    print(i)
# Out:
# 5

# %%
lst=[1,2,3,4,5,6,7,8,9]
to_search=int(input())
for i in range(0,len(lst)-1):
  if lst[i]==to_search:
    print(i)
# Out:
# 5
# 4

# %%
lst=[1,2,3,4,5,6,7,8,9]
to_search=int(input())
start=0
end=len(lst)-1
mid=(start+end)//2
for i in range(0,len(lst)-1):
 if lst[mid]==to_search:
   print(f"found at {mid} index")
   break
 elif lst[mid]>to_search:
  end=mid-1
  mid=(start+end)//2
 else:
  start=mid+1
  mid=(start+end)//2
# Out:
# 4
# found at 3 index

# %%
n=int(input())
base=int(input())
count=0
while n!=1:
  count+=1
  n//=base
print(f"log{n} base{base},count{count}")
# Out:
# 15
# 3
# log1 base3,count2

# %%
print(ord('A'))
# Out:
# 65

# %%
string=input("enter a string")
re
