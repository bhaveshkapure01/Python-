# %%
#Question no 2
from scipy.stats import binom
coin=binom.rvs(n=5,p=0.5)
print(coin)
# Out:
# probability= 3.818985064877954e-05

# %%
#Question no 3
from scipy.stats import poisson
lam=2
x=10
probability=poisson.pmf(x,lam)
print("probability=",probability)
# Out:
# 2

# %%
#Question no 4
from scipy.stats import geom
data=geom.rvs(p=0.5,size=10)
print(max(data))
# Out:
# 6

# %%
#Question no 5
from scipy.stats import binom
coin=binom.rvs(n=5,p=0.5)
print(coin)

from scipy.stats import geom
data=geom.rvs(p=0.5,size=10)
print(max(data))

from scipy.stats import poisson
lam=2
x=10
probability=poisson.pmf(x,lam)
print("probability=",probability)
# Out:
# 5
# 3
# probability= 3.818985064877954e-05
